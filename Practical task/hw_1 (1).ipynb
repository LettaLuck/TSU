# %% [markdown]
# # Практическое задание 1 (обязательное)

# %% [markdown]
# Шаг 1.  Изучите материалы лекционных и практических занятий по теме 2.2-2.4.
#
# Шаг 2. Создайте структуру данных, описывающую закрытую социальную сеть.  Используйте списки и словари для установления взаимосвязей пользователей (Алгоритм выполнения представлен в практическом занятии (мастер-классе) по теме 2.2 ).
#
# Шаг 3. Создайте функцию, определяющую количество друзей у выбранного пользователя (Алгоритм выполнения представлен в практическом занятии (мастер-классе) по теме 2.3 ).
#
# Шаг 4. Создайте функцию, выводящую на экран пользователей, отсортированных по количеству друзей (Алгоритм выполнения представлен в практическом занятии (мастер-классе) по теме 2.3 ).
#
# Шаг 5. Опубликуйте ссылку на файл расширения ipynb, прикрепив его в этом задании.
#
# Задание оценивается по системе 0–1–2 балла, где 0 – «не зачтено», 1 – «доработать», 2 – «зачтено»

# %% [markdown]
# ## Исходные данные
#
# В словаре `dict_users_network` заданы взаимосвязи (`дружба`) пользователей социальной сети, где `ключ` -- имя пользователя; `значение` -- список друзей пользователя. Для простоты будем считать, что оношение `дружба` не является биективным, т.е. если у `A` другом является `B`, то не обязательно, что у `B` в друзьях `A`.
#
# ## Задание (обязательное)
# - Создайте функцию, определяющую количество друзей у выбранного (каждого) пользователя.
# - Создайте функцию, выводящую на экран пользователей, отсортированных по количеству друзей.
# - Опубликуйте ссылку на файл расширения `ipynb`, прикрепив его в этом задании.
#
# ## Задание (факультативное)
# - Создайте функцию, определяющую наличие однофамильцев.
# - Создайте функцию, определяющую наличие пользователей с одинаковыми инициалами.
# - Создайте функцию, возвращающую список уникальных пользователей сети в формате `Фамилия И.О.`.
# - Создайте функцию, возвращающую список из уникальных фамилий  пользователей сети.

# %%
dict_users_network = ({
    'С.В. Сидоров' : ['П.В. Сидоров', 'И.И. Иванов', 'А.С. Никифоров', 
                      'Ф.С. Афеногонов', 'А.К. Парфенов'],
    'П.В. Сидоров' : ['С.В. Сидоров', 'А.С. Шебалова', 'М.Л. Кривов'],
    'И.И. Иванов' : ['Л.Т. Тимофеев', 'С.В. Сидоров', 'П.В. Сидоров', 
                     'М.Л. Кривов'],
    'А.С. Никифоров' : ['С.В. Сидоров', 'П.В. Сидоров'],                 
    'Ф.С. Афеногонов' : ['С.В. Сидоров', 'П.В. Сидоров', 'А.К. Парфенов'],
    'А.С. Шебалова' : ['Л.Т. Тимофеев'],
    'Л.Т. Тимофеев' : ['К.К. Петров', 'А.С. Крылов']
                     })

# 1
quantity_friends(dict_users_network)

def sorting_qf():
    pass

def namesakes():
    pass

def initials():
    pass

def ifo():
    pass

def family():
    pass

sort_list_user(dict_users_network)
# Out:
# Количество друзей пользователя С.В. Сидоров - 5
# Количество друзей пользователя П.В. Сидоров - 3
# Количество друзей пользователя И.И. Иванов - 4
# Количество друзей пользователя А.С. Никифоров - 2
# Количество друзей пользователя Ф.С. Афеногонов - 3
# Количество друзей пользователя А.С. Шебалова - 1
# Количество друзей пользователя Л.Т. Тимофеев - 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-55f1a4f7fd4c> in <module>()
#      29     pass
#      30
# ---> 31 sort_list_user(dict_users_network)
#
# NameError: name 'sort_list_user' is not defined

# %%
#1 Создайте функцию, определяющую количество друзей у выбранного (каждого) пользователя
def quantity_friends(enter_dict):
    users = list(enter_dict.keys())
    for i in users:
        print('Количество друзей пользователя', i, '-', len(enter_dict[i])) 

quantity_friends(dict_users_network)

# %%
#2 Создайте функцию, выводящую на экран пользователей, отсортированных по количеству друзей

def sorting_qf(enter_dict):
    print('Список пользователей, отсортироанных по количеству друзей:')
    

    pass

# %%
# Out:
# 7
# None

# %%
def sort_list_user(dict_users):
    lst_tmp = list()
    for key in dict_users.keys():
        lst_tmp.append((len(dict_users_network[key]), key))
    print("Список пользователей, отсортированных по количеству друзей:")
    for tpl in sorted(lst_tmp, reverse = True):
        print("     пользователь {}. Количество друзей - {}.".format(tpl[1], tpl[0]))

sort_list_user(dict_users_network)
# Out:
# Список пользователей, отсортированных по количеству друзей:
#      пользователь С.В. Сидоров. Количество друзей - 5.
#      пользователь И.И. Иванов. Количество друзей - 4.
#      пользователь Ф.С. Афеногонов. Количество друзей - 3.
#      пользователь П.В. Сидоров. Количество друзей - 3.
#      пользователь Л.Т. Тимофеев. Количество друзей - 2.
#      пользователь А.С. Никифоров. Количество друзей - 2.
#      пользователь А.С. Шебалова. Количество друзей - 1.

# %%
#3 Создайте функцию, определяющую наличие однофамильцев

# %%
#4 Создайте функцию, определяющую наличие пользователей с одинаковыми инициалами

# %%
#5 Создайте функцию, возвращающую список уникальных пользователей сети в формате Фамилия И.О.

# %%
#6 Создайте функцию, возвращающую список из уникальных фамилий пользователей сети
